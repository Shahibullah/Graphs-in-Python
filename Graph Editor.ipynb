# %%
import matplotlib.pyplot as plt

E = [54.20,13.5,6.05,3.37,2.16,1.49,1.11,0.84]

r = [1,2,3,4,5,6,7,8]

V = [53.8,27,18,13.5,10.8,9,7.7,6.7]

plt.plot(r, V, color='red', linestyle='dashed', linewidth = 3,
         marker='o', markerfacecolor='blue', markersize=6)

plt.xlabel('Distance (m)')
plt.ylabel('Electric Field (V/m)')
plt.grid()
plt.title('Electric Field vs Distance Plot')
plt.show()

print(" ")
print("==== Line Break ====")
print(" ")

plt.plot(r, E, color='red', linestyle='dashed', linewidth = 3,
         marker='o', markerfacecolor='blue', markersize=6)

plt.xlabel('Distance (m)')
plt.ylabel('Voltage (V)')
plt.grid()
plt.title('Voltage vs Distance Plot')
plt.show()
# Out:
#
# ==== Line Break ====
